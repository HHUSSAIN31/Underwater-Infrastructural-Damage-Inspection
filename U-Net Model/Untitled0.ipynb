# %%
# %cd '/content/drive/MyDrive/cracks'
# Out:
# [WinError 3] The system cannot find the path specified: "'/content/drive/MyDrive/cracks'"
# c:\Users\Dell\Documents\Thesis-CrackDetection\U-Net-Model\cracks

# %%
# !unzip 'crack-segmentation.zip' -d 'crack-segmentation'
# Out:
# Archive:  crack-segmentation.zip
#   inflating: crack-segmentation/crack-segmentation-main/.gitignore
#   inflating: crack-segmentation/crack-segmentation-main/.pre-commit-config.yaml
#    creating: crack-segmentation/crack-segmentation-main/crackseg/
#  extracting: crack-segmentation/crack-segmentation-main/crackseg/__init__.py
#    creating: crack-segmentation/crack-segmentation-main/crackseg/__pycache__/
#   inflating: crack-segmentation/crack-segmentation-main/crackseg/__pycache__/__init__.cpython-311.pyc
#    creating: crack-segmentation/crack-segmentation-main/crackseg/models/
#  extracting: crack-segmentation/crack-segmentation-main/crackseg/models/__init__.py
#    creating: crack-segmentation/crack-segmentation-main/crackseg/models/__pycache__/
#   inflating: crack-segmentation/crack-segmentation-main/crackseg/models/__pycache__/__init__.cpython-311.pyc
#   inflating: crack-segmentation/crack-segmentation-main/crackseg/models/__pycache__/unet.cpython-311.pyc
# ...

# %%
# %cd /content/drive/MyDrive/cracks/crack-segmentation/crack-segmentation-main
# %cd C:/Users/Dell/Documents/Thesis-CrackDetection/U-Net-Model/cracks/crack-segmentation
# Out:
# C:\Users\Dell\Documents\Thesis-CrackDetection\U-Net-Model\cracks\crack-segmentation

# %%
# !python train.py
# Out:
# python: can't open file 'C:\\Users\\Dell\\Documents\\Thesis-CrackDetection\\U-Net-Model\\cracks\\crack-segmentation\\train.py': [Errno 2] No such file or directory

# %%
# !python inference.py
# Out:
# 100% 249/249 [00:35<00:00,  7.00it/s]
